# %%
import pandas as pd
import numpy as np
import datetime
import pymongo
from sodapy import Socrata

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
db = client.squirrels_db

# Declare the collection
squirrels = db.squirrels

# %%
client_ny = Socrata("data.cityofnewyork.us", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client_ny.get("vfnx-vebw", limit=4000)

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#                       x                 y unique_squirrel_id hectare shift  \
# 0     -73.9561344937861  40.7940823884086     37F-PM-1014-03     37F    PM
# 1     -73.9688574691102  40.7837825208444     21B-AM-1019-04     21B    AM
# 2     -73.9742811484852   40.775533619083     11B-PM-1014-08     11B    PM
# 3     -73.9596413903948  40.7903128889029     32E-PM-1017-14     32E    PM
# 4     -73.9702676472613  40.7762126854894     13E-AM-1017-05     13E    AM
# ...                 ...               ...                ...     ...   ...
# 3018  -73.9639431360458  40.7908677445466     30B-AM-1007-04     30B    AM
# 3019  -73.9704015859639  40.7825600069973     19A-PM-1013-05     19A    PM
# 3020  -73.9665871993517  40.7836775064883     22D-PM-1012-07     22D    PM
# 3021  -73.9639941227864  40.7899152327912     29B-PM-1010-02     29B    PM
# 3022  -73.9754794191553  40.7696404489025      5E-PM-1012-01     05E    PM
#
#           date hectare_squirrel_number   combination_of_primary_and  running  \
# 0     10142018                       3                            +    False
# 1     10192018                       4                            +    False
# 2     10142018                       8                        Gray+    False
# 3     10172018                      14                        Gray+    False
# 4     10172018                       5                Gray+Cinnamon    False
# ...        ...                     ...                          ...      ...
# 3018  10072018                       4                        Gray+    False
# 3019  10132018                       5                   Gray+White    False
# 3020  10122018                       7  Gray+Black, Cinnamon, White    False
# 3021  10102018                       2         Gray+Cinnamon, White    False
# 3022  10122018                       1         Cinnamon+Gray, White    False
#
#       chasing  ...  primary_fur_color      location  above_ground_sighter  \
# 0       False  ...                NaN           NaN                   NaN
# 1       False  ...                NaN           NaN                   NaN
# 2        True  ...               Gray  Above Ground                    10
# 3       False  ...               Gray           NaN                   NaN
# 4       False  ...               Gray  Above Ground                   NaN
# ...       ...  ...                ...           ...                   ...
# 3018    False  ...               Gray  Ground Plane                 FALSE
# 3019    False  ...               Gray  Ground Plane                 FALSE
# 3020    False  ...               Gray  Ground Plane                 FALSE
# 3021    False  ...               Gray  Ground Plane                 FALSE
# 3022    False  ...           Cinnamon  Ground Plane                 FALSE
#
#         age                                        color_notes  \
# 0       NaN                                                NaN
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3     Adult  Nothing selected as Primary. Gray selected as ...
# 4     Adult                                                NaN
# ...     ...                                                ...
# 3018  Adult                                                NaN
# 3019  Adult                                                NaN
# 3020  Adult                                                NaN
# 3021    NaN                                                NaN
# 3022  Adult                                                NaN
#
#          highlight_fur_color  specific_location  other_activities  \
# 0                        NaN                NaN               NaN
# 1                        NaN                NaN               NaN
# 2                        NaN                NaN               NaN
# 3                        NaN                NaN               NaN
# 4                   Cinnamon      on tree stump               NaN
# ...                      ...                ...               ...
# 3018                     NaN                NaN               NaN
# 3019                   White                NaN               NaN
# 3020  Black, Cinnamon, White                NaN               NaN
# 3021         Cinnamon, White                NaN               NaN
# 3022             Gray, White                NaN               NaN
#
#       other_interactions  :@computed_region_efsh_h5xi
# 0                    NaN                          NaN
# 1                    NaN                          NaN
# 2                    NaN                          NaN
# 3                    NaN                          NaN
# 4                    NaN                          NaN
# ...                  ...                          ...
# 3018                 NaN                          NaN
# 3019                 NaN                          NaN
# 3020                 NaN                          NaN
# 3021                 NaN                          NaN
# 3022                 NaN                          NaN
#
# [3023 rows x 36 columns]

# %%
results_df_2 = results_df.replace(np.nan, '', regex=True)

# %%
#Checking for duplicates
results_df_2.unique_squirrel_id.nunique()
# Out:
# 3018

# %%
#Printing duplicate ids
d = results_df_2['unique_squirrel_id'].duplicated()
duplicates = results_df_2[d]
duplicates
# Out:
#                       x                 y unique_squirrel_id hectare shift  \
# 2167  -73.9582363437135  40.7987752300505     40B-AM-1019-06     40B    AM
# 2234  -73.9748522796455  40.7719586621003      7D-PM-1010-01     07D    PM
# 2271  -73.9569670900695  40.7948792856813     37E-PM-1006-03     37E    PM
# 2613  -73.9765877920583  40.7660946071574      1F-AM-1010-04     01F    AM
# 2888  -73.9771646835311  40.7693049165084      4C-PM-1010-05     04C    PM
#
#           date hectare_squirrel_number combination_of_primary_and  running  \
# 2167  10192018                       6                 Gray+White    False
# 2234  10102018                       1                 Gray+White     True
# 2271  10062018                       3              Gray+Cinnamon     True
# 2613  10102018                       4                      Gray+    False
# 2888  10102018                       5              Gray+Cinnamon     True
#
#       chasing  ...  primary_fur_color      location  above_ground_sighter  \
# 2167    False  ...               Gray  Ground Plane                 FALSE
# 2234    False  ...               Gray  Ground Plane                 FALSE
# 2271    False  ...               Gray  Ground Plane                 FALSE
# 2613    False  ...               Gray  Ground Plane                 FALSE
# 2888    False  ...               Gray  Ground Plane                 FALSE
#
#            age  color_notes  highlight_fur_color       specific_location  \
# 2167  Juvenile                             White
# 2234     Adult                             White  outside fenced hectare
# 2271     Adult                          Cinnamon
# 2613     Adult
# 2888     Adult                          Cinnamon
#
#       other_activities  other_interactions  :@computed_region_efsh_h5xi
# 2167
# 2234
# 2271                                    me
# 2613
# 2888
#
# [5 rows x 36 columns]

# %%
#Locating duplicate for squirrel id 40B-AM-1019-06
results_df_2.loc[results_df_2['unique_squirrel_id'] == '40B-AM-1019-06']
# Out:
#                       x                 y unique_squirrel_id hectare shift  \
# 1540   -73.957710975899  40.7984055614047     40B-AM-1019-06     40B    AM
# 2167  -73.9582363437135  40.7987752300505     40B-AM-1019-06     40B    AM
#
#           date hectare_squirrel_number combination_of_primary_and  running  \
# 1540  10192018                       6                 Gray+White    False
# 2167  10192018                       6                 Gray+White    False
#
#       chasing  ...  primary_fur_color      location  above_ground_sighter  \
# 1540    False  ...               Gray  Ground Plane                 FALSE
# 2167    False  ...               Gray  Ground Plane                 FALSE
#
#            age  color_notes  highlight_fur_color  specific_location  \
# 1540  Juvenile                             White
# 2167  Juvenile                             White
#
#       other_activities  other_interactions  :@computed_region_efsh_h5xi
# 1540
# 2167
#
# [2 rows x 36 columns]

# %%
#Keeping the first recorded sighting for the duplicate squirrel entries
results_df_3= results_df_2.drop_duplicates(subset='unique_squirrel_id', keep="first")

# %%
results_df_3
# Out:
#                       x                 y unique_squirrel_id hectare shift  \
# 0     -73.9561344937861  40.7940823884086     37F-PM-1014-03     37F    PM
# 1     -73.9688574691102  40.7837825208444     21B-AM-1019-04     21B    AM
# 2     -73.9742811484852   40.775533619083     11B-PM-1014-08     11B    PM
# 3     -73.9596413903948  40.7903128889029     32E-PM-1017-14     32E    PM
# 4     -73.9702676472613  40.7762126854894     13E-AM-1017-05     13E    AM
# ...                 ...               ...                ...     ...   ...
# 3018  -73.9639431360458  40.7908677445466     30B-AM-1007-04     30B    AM
# 3019  -73.9704015859639  40.7825600069973     19A-PM-1013-05     19A    PM
# 3020  -73.9665871993517  40.7836775064883     22D-PM-1012-07     22D    PM
# 3021  -73.9639941227864  40.7899152327912     29B-PM-1010-02     29B    PM
# 3022  -73.9754794191553  40.7696404489025      5E-PM-1012-01     05E    PM
#
#           date hectare_squirrel_number   combination_of_primary_and  running  \
# 0     10142018                       3                            +    False
# 1     10192018                       4                            +    False
# 2     10142018                       8                        Gray+    False
# 3     10172018                      14                        Gray+    False
# 4     10172018                       5                Gray+Cinnamon    False
# ...        ...                     ...                          ...      ...
# 3018  10072018                       4                        Gray+    False
# 3019  10132018                       5                   Gray+White    False
# 3020  10122018                       7  Gray+Black, Cinnamon, White    False
# 3021  10102018                       2         Gray+Cinnamon, White    False
# 3022  10122018                       1         Cinnamon+Gray, White    False
#
#       chasing  ...  primary_fur_color      location  above_ground_sighter  \
# 0       False  ...
# 1       False  ...
# 2        True  ...               Gray  Above Ground                    10
# 3       False  ...               Gray
# 4       False  ...               Gray  Above Ground
# ...       ...  ...                ...           ...                   ...
# 3018    False  ...               Gray  Ground Plane                 FALSE
# 3019    False  ...               Gray  Ground Plane                 FALSE
# 3020    False  ...               Gray  Ground Plane                 FALSE
# 3021    False  ...               Gray  Ground Plane                 FALSE
# 3022    False  ...           Cinnamon  Ground Plane                 FALSE
#
#         age                                        color_notes  \
# 0
# 1
# 2
# 3     Adult  Nothing selected as Primary. Gray selected as ...
# 4     Adult
# ...     ...                                                ...
# 3018  Adult
# 3019  Adult
# 3020  Adult
# 3021
# 3022  Adult
#
#          highlight_fur_color  specific_location  other_activities  \
# 0
# 1
# 2
# 3
# 4                   Cinnamon      on tree stump
# ...                      ...                ...               ...
# 3018
# 3019                   White
# 3020  Black, Cinnamon, White
# 3021         Cinnamon, White
# 3022             Gray, White
#
#       other_interactions  :@computed_region_efsh_h5xi
# 0
# 1
# 2
# 3
# 4
# ...                  ...                          ...
# 3018
# 3019
# 3020
# 3021
# 3022
#
# [3018 rows x 36 columns]

# %%
results_df_3.set_index('unique_squirrel_id', inplace=True)

# %%
results_df_3
# Out:
#                                     x                 y hectare shift  \
# unique_squirrel_id
# 37F-PM-1014-03      -73.9561344937861  40.7940823884086     37F    PM
# 21B-AM-1019-04      -73.9688574691102  40.7837825208444     21B    AM
# 11B-PM-1014-08      -73.9742811484852   40.775533619083     11B    PM
# 32E-PM-1017-14      -73.9596413903948  40.7903128889029     32E    PM
# 13E-AM-1017-05      -73.9702676472613  40.7762126854894     13E    AM
# ...                               ...               ...     ...   ...
# 30B-AM-1007-04      -73.9639431360458  40.7908677445466     30B    AM
# 19A-PM-1013-05      -73.9704015859639  40.7825600069973     19A    PM
# 22D-PM-1012-07      -73.9665871993517  40.7836775064883     22D    PM
# 29B-PM-1010-02      -73.9639941227864  40.7899152327912     29B    PM
# 5E-PM-1012-01       -73.9754794191553  40.7696404489025     05E    PM
#
#                         date hectare_squirrel_number  \
# unique_squirrel_id
# 37F-PM-1014-03      10142018                       3
# 21B-AM-1019-04      10192018                       4
# 11B-PM-1014-08      10142018                       8
# 32E-PM-1017-14      10172018                      14
# 13E-AM-1017-05      10172018                       5
# ...                      ...                     ...
# 30B-AM-1007-04      10072018                       4
# 19A-PM-1013-05      10132018                       5
# 22D-PM-1012-07      10122018                       7
# 29B-PM-1010-02      10102018                       2
# 5E-PM-1012-01       10122018                       1
#
#                      combination_of_primary_and  running  chasing  climbing  \
# unique_squirrel_id
# 37F-PM-1014-03                                +    False    False     False
# 21B-AM-1019-04                                +    False    False     False
# 11B-PM-1014-08                            Gray+    False     True     False
# 32E-PM-1017-14                            Gray+    False    False     False
# 13E-AM-1017-05                    Gray+Cinnamon    False    False     False
# ...                                         ...      ...      ...       ...
# 30B-AM-1007-04                            Gray+    False    False     False
# 19A-PM-1013-05                       Gray+White    False    False     False
# 22D-PM-1012-07      Gray+Black, Cinnamon, White    False    False     False
# 29B-PM-1010-02             Gray+Cinnamon, White    False    False     False
# 5E-PM-1012-01              Cinnamon+Gray, White    False    False     False
#
#                     ...  primary_fur_color      location  \
# unique_squirrel_id  ...
# 37F-PM-1014-03      ...
# 21B-AM-1019-04      ...
# 11B-PM-1014-08      ...               Gray  Above Ground
# 32E-PM-1017-14      ...               Gray
# 13E-AM-1017-05      ...               Gray  Above Ground
# ...                 ...                ...           ...
# 30B-AM-1007-04      ...               Gray  Ground Plane
# 19A-PM-1013-05      ...               Gray  Ground Plane
# 22D-PM-1012-07      ...               Gray  Ground Plane
# 29B-PM-1010-02      ...               Gray  Ground Plane
# 5E-PM-1012-01       ...           Cinnamon  Ground Plane
#
#                     above_ground_sighter    age  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08                        10
# 32E-PM-1017-14                            Adult
# 13E-AM-1017-05                            Adult
# ...                                  ...    ...
# 30B-AM-1007-04                     FALSE  Adult
# 19A-PM-1013-05                     FALSE  Adult
# 22D-PM-1012-07                     FALSE  Adult
# 29B-PM-1010-02                     FALSE
# 5E-PM-1012-01                      FALSE  Adult
#
#                                                           color_notes  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14      Nothing selected as Primary. Gray selected as ...
# 13E-AM-1017-05
# ...                                                               ...
# 30B-AM-1007-04
# 19A-PM-1013-05
# 22D-PM-1012-07
# 29B-PM-1010-02
# 5E-PM-1012-01
#
#                        highlight_fur_color  specific_location  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14
# 13E-AM-1017-05                    Cinnamon      on tree stump
# ...                                    ...                ...
# 30B-AM-1007-04
# 19A-PM-1013-05                       White
# 22D-PM-1012-07      Black, Cinnamon, White
# 29B-PM-1010-02             Cinnamon, White
# 5E-PM-1012-01                  Gray, White
#
#                     other_activities  other_interactions  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14
# 13E-AM-1017-05
# ...                              ...                 ...
# 30B-AM-1007-04
# 19A-PM-1013-05
# 22D-PM-1012-07
# 29B-PM-1010-02
# 5E-PM-1012-01
#
#                     :@computed_region_efsh_h5xi
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14
# 13E-AM-1017-05
# ...                                         ...
# 30B-AM-1007-04
# 19A-PM-1013-05
# 22D-PM-1012-07
# 29B-PM-1010-02
# 5E-PM-1012-01
#
# [3018 rows x 35 columns]

# %%
#Inspecting column types
print (results_df_3.dtypes)
# Out:
# x                              object
# y                              object
# hectare                        object
# shift                          object
# date                           object
# hectare_squirrel_number        object
# combination_of_primary_and     object
# running                          bool
# chasing                          bool
# climbing                         bool
# eating                           bool
# foraging                         bool
# kuks                             bool
# quaas                            bool
# moans                            bool
# tail_flags                       bool
# tail_twitches                    bool
# approaches                       bool
# indifferent                      bool
# runs_from                        bool
# geocoded_column                object
# :@computed_region_f5dn_yrer    object
# :@computed_region_yeji_bk3q    object
# :@computed_region_92fq_4b7q    object
# :@computed_region_sbqj_enih    object
# primary_fur_color              object
# location                       object
# above_ground_sighter           object
# age                            object
# color_notes                    object
# highlight_fur_color            object
# specific_location              object
# other_activities               object
# other_interactions             object
# :@computed_region_efsh_h5xi    object
# dtype: object

# %%
#Convert date string to date format
# df['DataFrame Column'] = pd.to_datetime(df['DataFrame Column'], format=specify your format)
results_df_3['date'] = pd.to_datetime(results_df_3['date'], format='%m%d%Y')
results_df_3
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                     x                 y hectare shift  \
# unique_squirrel_id
# 37F-PM-1014-03      -73.9561344937861  40.7940823884086     37F    PM
# 21B-AM-1019-04      -73.9688574691102  40.7837825208444     21B    AM
# 11B-PM-1014-08      -73.9742811484852   40.775533619083     11B    PM
# 32E-PM-1017-14      -73.9596413903948  40.7903128889029     32E    PM
# 13E-AM-1017-05      -73.9702676472613  40.7762126854894     13E    AM
# ...                               ...               ...     ...   ...
# 30B-AM-1007-04      -73.9639431360458  40.7908677445466     30B    AM
# 19A-PM-1013-05      -73.9704015859639  40.7825600069973     19A    PM
# 22D-PM-1012-07      -73.9665871993517  40.7836775064883     22D    PM
# 29B-PM-1010-02      -73.9639941227864  40.7899152327912     29B    PM
# 5E-PM-1012-01       -73.9754794191553  40.7696404489025     05E    PM
#
#                          date hectare_squirrel_number  \
# unique_squirrel_id
# 37F-PM-1014-03     2018-10-14                       3
# 21B-AM-1019-04     2018-10-19                       4
# 11B-PM-1014-08     2018-10-14                       8
# 32E-PM-1017-14     2018-10-17                      14
# 13E-AM-1017-05     2018-10-17                       5
# ...                       ...                     ...
# 30B-AM-1007-04     2018-10-07                       4
# 19A-PM-1013-05     2018-10-13                       5
# 22D-PM-1012-07     2018-10-12                       7
# 29B-PM-1010-02     2018-10-10                       2
# 5E-PM-1012-01      2018-10-12                       1
#
#                      combination_of_primary_and  running  chasing  climbing  \
# unique_squirrel_id
# 37F-PM-1014-03                                +    False    False     False
# 21B-AM-1019-04                                +    False    False     False
# 11B-PM-1014-08                            Gray+    False     True     False
# 32E-PM-1017-14                            Gray+    False    False     False
# 13E-AM-1017-05                    Gray+Cinnamon    False    False     False
# ...                                         ...      ...      ...       ...
# 30B-AM-1007-04                            Gray+    False    False     False
# 19A-PM-1013-05                       Gray+White    False    False     False
# 22D-PM-1012-07      Gray+Black, Cinnamon, White    False    False     False
# 29B-PM-1010-02             Gray+Cinnamon, White    False    False     False
# 5E-PM-1012-01              Cinnamon+Gray, White    False    False     False
#
#                     ...  primary_fur_color      location  \
# unique_squirrel_id  ...
# 37F-PM-1014-03      ...
# 21B-AM-1019-04      ...
# 11B-PM-1014-08      ...               Gray  Above Ground
# 32E-PM-1017-14      ...               Gray
# 13E-AM-1017-05      ...               Gray  Above Ground
# ...                 ...                ...           ...
# 30B-AM-1007-04      ...               Gray  Ground Plane
# 19A-PM-1013-05      ...               Gray  Ground Plane
# 22D-PM-1012-07      ...               Gray  Ground Plane
# 29B-PM-1010-02      ...               Gray  Ground Plane
# 5E-PM-1012-01       ...           Cinnamon  Ground Plane
#
#                     above_ground_sighter    age  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08                        10
# 32E-PM-1017-14                            Adult
# 13E-AM-1017-05                            Adult
# ...                                  ...    ...
# 30B-AM-1007-04                     FALSE  Adult
# 19A-PM-1013-05                     FALSE  Adult
# 22D-PM-1012-07                     FALSE  Adult
# 29B-PM-1010-02                     FALSE
# 5E-PM-1012-01                      FALSE  Adult
#
#                                                           color_notes  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14      Nothing selected as Primary. Gray selected as ...
# 13E-AM-1017-05
# ...                                                               ...
# 30B-AM-1007-04
# 19A-PM-1013-05
# 22D-PM-1012-07
# 29B-PM-1010-02
# 5E-PM-1012-01
#
#                        highlight_fur_color  specific_location  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14
# 13E-AM-1017-05                    Cinnamon      on tree stump
# ...                                    ...                ...
# 30B-AM-1007-04
# 19A-PM-1013-05                       White
# 22D-PM-1012-07      Black, Cinnamon, White
# 29B-PM-1010-02             Cinnamon, White
# 5E-PM-1012-01                  Gray, White
#
#                     other_activities  other_interactions  \
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14
# 13E-AM-1017-05
# ...                              ...                 ...
# 30B-AM-1007-04
# 19A-PM-1013-05
# 22D-PM-1012-07
# 29B-PM-1010-02
# 5E-PM-1012-01
#
#                     :@computed_region_efsh_h5xi
# unique_squirrel_id
# 37F-PM-1014-03
# 21B-AM-1019-04
# 11B-PM-1014-08
# 32E-PM-1017-14
# 13E-AM-1017-05
# ...                                         ...
# 30B-AM-1007-04
# 19A-PM-1013-05
# 22D-PM-1012-07
# 29B-PM-1010-02
# 5E-PM-1012-01
#
# [3018 rows x 35 columns]

# %%
db.squirrels.insert({id: results_df_3.to_json()})
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-19-8c94fc6c63e2> in <module>
# ----> 1 db.squirrels.insert({id: results_df_3.to_json()})
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    3292             write_concern = WriteConcern(**kwargs)
#    3293         return self._insert(doc_or_docs, not continue_on_error,
# -> 3294                             check_keys, manipulate, write_concern)
#    3295
#    3296     def update(self, spec, document, upsert=False, manipulate=False,
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 615                 bypass_doc_val, session)
#     616
#     617         ids = []
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     601
#     602         self.__database.client._retryable_write(
# --> 603             acknowledged, _insert_command, session)
#     604
#     605         if not isinstance(doc, RawBSONDocument):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     596                 session=session,
#     597                 client=self.__database.client,
# --> 598                 retryable_write=retryable_write)
#     599
#     600             _check_write_command_response(result)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     697         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     698         except BaseException as error:
# --> 699             self._raise_connection_failure(error)
#     700
#     701     def send_message(self, message, max_doc_size):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     120         request_id, msg, size, max_doc_size = message._op_msg(
#     121             flags, spec, dbname, read_preference, slave_ok, check_keys,
# --> 122             codec_options, ctx=compression_ctx)
#     123         # If this is an unacknowledged write then make sure the encoded doc(s)
#     124         # are small enough, otherwise rely on the server to return an error.
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/message.py in _op_msg(flags, command, dbname, read_preference, slave_ok, check_keys, opts, ctx)
#     713                 flags, command, identifier, docs, check_keys, opts, ctx)
#     714         return _op_msg_uncompressed(
# --> 715             flags, command, identifier, docs, check_keys, opts)
#     716     finally:
#     717         # Add the field back to the command.
#
# InvalidDocument: documents must have only string keys, key was <built-in function id>

# %%
resultsdf.to_json(r'Path to store the exported JSON file\File Name.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4066af7ce102> in <module>
# ----> 1 resultsdf.to_json(r'Path to store the exported JSON file\File Name.json')
#
# NameError: name 'resultsdf' is not defined
